# %%
from bs4 import BeautifulSoup
import requests
import datetime
import time
import smtplib

# %%
URL = 'https://www.amazon.com/Apple-Version-Orange-Unlocked-Renewed/dp/B0FTC2PRVZ/ref=sr_1_3?crid=2S5X0OUN3TMBK&dib=eyJ2IjoiMSJ9.oiXA_-K93j869CYgRq0H3lQC9ChMYuLX1BdgGs5DZ_XcI9n2X6I1DPUmzo5FIsThxxvNvKDQWRTuZuIjVYuS5Vx7v3u9HFvr6qLSvaN2-nefGQX-Sb7fMDtt9eyonpmIsnu4uXf0iONm_erQ3KBoLQLYQfB_V_Bl8aOKLDNhqOfCXP2-hB637DNtNZTOhmq2Ibou7CjmaClfzC0aQq4ewGJT81sDPaWkidTzqAbCETY.RhzuJhypSbkoPYbJVEI9NXsNzPLVLcKFTGI-i0qDZj0&dib_tag=se&keywords=iphone&qid=1786604657&sprefix=ipho%2Caps%2C510&sr=8-3&th=1'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
}
page = requests.get(URL, headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
title = soup2.find(id='productTitle').get_text()
price = soup2.find('span', class_='a-price-whole').get_text()

print(title)
print(price)
# Out:
#            Apple iPhone 17 Pro Max, US Version, 256GB, eSIM, Cosmic Orange- Unlocked (Renewed)
#
#
#                             36,822
#
#                              .

# %%
title = title.strip()
print(title)
# Out:
# Apple iPhone 17 Pro Max, US Version, 256GB, eSIM, Cosmic Orange- Unlocked (Renewed)

# %%
price = price.strip(' .\n')
print(price)
# Out:
# 36,822

# %%
today = datetime.date.today()
print(today)
# Out:
# 2026-08-13

# %%
import csv

header = ['Product', 'Price', 'Date']
data = [title, price, today]

with open('output_data_from_web-scraper_amazon.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\phyop\output_data_from_web-scraper_amazon.csv")
df

# %%
with open('output_data_from_web-scraper_amazon.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com/Apple-Version-Orange-Unlocked-Renewed/dp/B0FTC2PRVZ/ref=sr_1_3?crid=2S5X0OUN3TMBK&dib=eyJ2IjoiMSJ9.oiXA_-K93j869CYgRq0H3lQC9ChMYuLX1BdgGs5DZ_XcI9n2X6I1DPUmzo5FIsThxxvNvKDQWRTuZuIjVYuS5Vx7v3u9HFvr6qLSvaN2-nefGQX-Sb7fMDtt9eyonpmIsnu4uXf0iONm_erQ3KBoLQLYQfB_V_Bl8aOKLDNhqOfCXP2-hB637DNtNZTOhmq2Ibou7CjmaClfzC0aQq4ewGJT81sDPaWkidTzqAbCETY.RhzuJhypSbkoPYbJVEI9NXsNzPLVLcKFTGI-i0qDZj0&dib_tag=se&keywords=iphone&qid=1786604657&sprefix=ipho%2Caps%2C510&sr=8-3&th=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36", "Accept-Language": "en-US,en;q=0.9", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",}
    page = requests.get(URL, headers=headers)
    
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find('span', class_='a-price-whole').get_text()
    
    title = title.strip()
    price = price.strip(' .\n')
    today = datetime.date.today()

    import csv
    header = ['Product', 'Price', 'Date']
    data = [title, price, today]

    with open('output_data_from_web-scraper_amazon.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(3600)
